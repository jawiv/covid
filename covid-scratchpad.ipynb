# %%
import requests
import pandas as pd
import numpy as np
import math
import json
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource
from bokeh.transform import factor_cmap
from bokeh.palettes import Spectral6
from IPython.display import Markdown as md
import os

output_notebook()
url = "http://bing.com/covid/data"
r = requests.get(url)
j = r.json()
with open('state_populations.json') as data:
    state_pop = pd.read_json(data)
#j = r.json()
#print(j)
#df = pd.DataFrame(j['areas'][2])
df = pd.json_normalize(j['areas'][2], 'areas')
#df['totalConfirmed'].sum()
index = df['displayName'].to_list()
totalConfirmed = df['totalConfirmed'].to_list()
totalDeaths = df['totalDeaths'].to_list()
totalRecovered = df['totalRecovered'].to_list()
df2 = pd.DataFrame({'totalConfirmed': totalConfirmed,
                    'totalDeaths': totalDeaths,
                    'totalRecovered': totalRecovered}, index=index)
df2['totalRecovered'].fillna(0, inplace=True)
df2['deathRate'] = df2['totalDeaths'].div(df2['totalConfirmed'], fill_value=0)
df2['recoveryRate'] = df2['totalRecovered'].div(df2['totalConfirmed'], fill_value=0)
covid = pd.merge(left=df2, right=state_pop[['state_name','population']], how='left', left_index=True, right_on='state_name')
covid['infectionRate'] = covid['totalConfirmed'].div(covid['population'], fill_value=0)
covid = covid[['state_name', 'population', 'totalConfirmed', 'infectionRate', 'totalDeaths', 'deathRate', 'totalRecovered', 'recoveryRate']]
covid.set_index('state_name', inplace=True)

total_population = int(covid['population'].sum())
total_confirmed = int(covid['totalConfirmed'].sum())
total_deaths = int(covid['totalDeaths'].sum())
total_recoveries = int(covid['totalRecovered'].sum())
infection_rate = total_confirmed / total_population
death_rate = total_deaths / total_confirmed
recovery_rate = total_recoveries / total_confirmed

covid['expected'] = covid['population'].mul(infection_rate)
covid['delta'] = covid['totalConfirmed'].sub(covid['expected'])
covid['deltaRate'] = covid['totalConfirmed'].div(covid['delta'])
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9011">Loading BokehJS ...</span>
#     </div>

# %%
var_list = [covid.loc['Tennessee', 'infectionRate']]
var_list.append(covid.loc['Tennessee', 'deathRate'])
var_list.append(int(covid.loc['Tennessee', 'delta']))
var_list.append(covid.loc['Tennessee', 'deltaRate'])
var_list.append(int(covid.loc['Tennessee', 'expected']))
var_list.append(int(covid.loc['Tennessee', 'totalConfirmed']))

tennessee = """**`Tennessee:`**  
Infection rate is **`{:.4%}`**   
Death rate is **`{:.4%}`**   
Actual/expected delta is **`{:,}`** or **`{:.4%}`**  
Expected Infections: **`{:,}`**  
Actual Infections: **`{:,}`**
""".format(*var_list)

#tennessee = "**`Tennessee`**:  "
#tennessee += "The current infection rate is **`{:.4%}`**.  ".format(covid.loc['Tennessee', 'infectionRate'])
#tennessee += "The current death rate is **`{:.4%}`**.  ".format(covid.loc['Tennessee', 'deathRate'])
#tennessee += "The current actual/expected delta is **`{:,}`** or **`{:.4%}`**.  ".format(int(covid.loc['Tennessee', 'delta']), covid.loc['Tennessee', 'deltaRate'])
md(tennessee)
# Out:
# **`Tennessee:`**
# Infection rate is **`0.0114%`**
# Death rate is **`0.3827%`**
# Actual/expected delta is **`-550`** or **`-142.4623%`**
# Expected Infections: **`1,334`**
# Actual Infections: **`784`**

# %%
df.describe()
# Out:
#        totalConfirmed  totalDeaths  totalRecovered        lat        long
# count       51.000000    40.000000       16.000000  51.000000   51.000000
# mean      1165.470588    19.750000       18.750000  39.577923  -93.475285
# std       4296.872860    48.074061       40.824013   6.322399   19.157176
# min         39.000000     1.000000        1.000000  19.598518 -155.518555
# 25%        106.000000     2.000000        1.750000  35.712851 -103.008621
# 50%        290.000000     6.500000        3.000000  39.356419  -89.656242
# 75%        753.500000    12.500000        8.500000  43.342552  -78.941738
# max      30811.000000   285.000000      124.000000  63.174122  -69.203949

# %%
source = ColumnDataSource(data=covid)

title_p = "COVID Confirmed: {:,} - Death Rate: {:.4%} - Recovery Rate: {:.4%}".format(total_confirmed, death_rate, recovery_rate)
title_q = "COVID Deaths: {:,} - Death Rate: {:.4%}".format(total_deaths, death_rate)
title_z = "COVID Recovered: {:,} - Recovery Rate: {:.4%}".format(total_recoveries, recovery_rate)
title_x = "COVID US National Infection Rate: {:.4%}".format(infection_rate)
title_y = "COVID US Confirmed / Expected Delta"

p = figure(x_range=index, plot_height=800, plot_width=1500, title=title_p)
p.vbar(x='state_name', top='totalConfirmed', width=0.1, source=source, line_color='white')
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = covid['totalConfirmed'].max() + 1000
p.xaxis.major_label_orientation = math.pi / 4

q = figure(x_range=index, plot_height=800, plot_width=1500, title=title_q)
q.vbar(x='state_name', top='totalDeaths', width=0.1, source=source, line_color='white')
q.xgrid.grid_line_color = None
q.y_range.start = 0
q.y_range.end = covid['totalDeaths'].max() + 100
q.xaxis.major_label_orientation = math.pi / 4

z = figure(x_range=index, plot_height=800, plot_width=1500, title=title_z)
z.vbar(x='state_name', top='totalRecovered', width=0.1, source=source, line_color='white')
z.xgrid.grid_line_color = None
z.y_range.start = 0
z.y_range.end = covid['totalRecovered'].max() + 50
z.xaxis.major_label_orientation = math.pi / 4

x = figure(x_range=index, plot_height=800, plot_width=1500, title=title_x)
x.vbar(x='state_name', top='infectionRate', width=0.1, source=source)
x.xgrid.grid_line_color = None
x.y_range.start = 0
x.y_range.end = covid['infectionRate'].max() + 0.0005
x.xaxis.major_label_orientation = math.pi / 4

y = figure(x_range=index, plot_height=800, plot_width=1500, title=title_y)
y.vbar(x='state_name', top='delta', width=0.1, source=source)
y.xgrid.grid_line_color = None
y.y_range.start = covid['delta'].min() - 500
y.y_range.end = covid['delta'].max() + 500
y.xaxis.major_label_orientation = math.pi / 4

show(x)
show(y)
show(p)
show(q)
show(z)
# Out:
#   <div class="bk-root" id="ba73deb1-7814-45e0-a296-8f630c6d5eab" data-root-id="7419"></div>
#   <div class="bk-root" id="0ec070f8-2d00-4895-9f13-ed68defce9e2" data-root-id="7455"></div>
#   <div class="bk-root" id="7d4ec930-5c16-472e-8d9f-0a04b418d066" data-root-id="7311"></div>
#   <div class="bk-root" id="62afb854-87c9-4e78-98c4-ddc685b0005b" data-root-id="7347"></div>
#   <div class="bk-root" id="84edf8fd-a7a1-4174-b406-fd2b4075820f" data-root-id="7383"></div>

# %%
#ax = df2.plot.bar(rot=45, figsize=(25,5))

covid.head(80)
# Out:
#                       population  totalConfirmed  infectionRate  totalDeaths  \
# state_name
# New York                19440469           30811       0.001585        108.0
# New Jersey               8936574            4402       0.000493         65.0
# California              39937489            2617       0.000066         55.0
# Washington               7797095            2469       0.000317        123.0
# Michigan                10045029            2295       0.000228         43.0
# Illinois                12659682            1865       0.000147         19.0
# Massachusetts            6976597            1838       0.000263         11.0
# Louisiana                4645184            1795       0.000386         65.0
# Florida                 21992985            1682       0.000076         22.0
# Georgia                 10736059            1247       0.000116         40.0
# Pennsylvania            12820878            1127       0.000088         11.0
# Texas                   29472295             974       0.000033         12.0
# Colorado                 5845526             912       0.000156         11.0
# Connecticut              3563077             875       0.000246         12.0
# Tennessee                6897576             784       0.000114          3.0
# Ohio                    11747694             704       0.000060         10.0
# Wisconsin                5851754             585       0.000100          6.0
# North Carolina          10611862             504       0.000047          1.0
# Indiana                  6745354             477       0.000071         14.0
# South Carolina           5210095             424       0.000081          7.0
# Maryland                 6083116             423       0.000070          4.0
# Arizona                  7378494             401       0.000054          6.0
# Virginia                 8626207             391       0.000045          9.0
# Mississippi              2989260             377       0.000126          2.0
# Missouri                 6169270             356       0.000058          5.0
# Utah                     3282115             346       0.000105          1.0
# Minnesota                5700671             287       0.000050          1.0
# Alabama                  4908921             283       0.000058          NaN
# Arkansas                 3038999             280       0.000092          2.0
# Nevada                   3139658             321       0.000102          6.0
# Oregon                   4301089             209       0.000049          8.0
# District of Columbia      720687             183       0.000254          2.0
# Oklahoma                 3954821             164       0.000041          5.0
# Kentucky                 4499692             157       0.000035          4.0
# Iowa                     3179849             154       0.000048          NaN
# Maine                    1345790             142       0.000106          3.0
# Kansas                   2910357             126       0.000043          3.0
# Rhode Island             1056161             124       0.000117          NaN
# Vermont                   628061             123       0.000196          7.0
# New Hampshire            1371246             108       0.000079          1.0
# Delaware                  982895             115       0.000117          NaN
# New Mexico               2096640             100       0.000048          NaN
# Hawaii                   1412687              90       0.000064          1.0
# Idaho                    1826156              73       0.000040          NaN
# Nebraska                 1952570              61       0.000031          NaN
# Montana                  1086759              53       0.000049          NaN
# Alaska                    734002              42       0.000057          1.0
# South Dakota              903027              41       0.000045          1.0
# North Dakota              761723              39       0.000051          NaN
# West Virginia            1778070              39       0.000022          NaN
# Wyoming                   567025              41       0.000072          NaN
#
#                       deathRate  totalRecovered  recoveryRate     expected  \
# state_name
# New York               0.003505           285.0      0.009250  3757.372127
# New Jersey             0.014766             2.0      0.000454  1727.223456
# California             0.021016             6.0      0.002293  7718.949990
# Washington             0.049818           124.0      0.050223  1506.989745
# Michigan               0.018736             0.0      0.000000  1941.460979
# Illinois               0.010188             2.0      0.001072  2446.810120
# Massachusetts          0.005985             1.0      0.000544  1348.407341
# Louisiana              0.036212             0.0      0.000000   897.801637
# Florida                0.013080             0.0      0.000000  4250.711689
# Georgia                0.032077             0.0      0.000000  2075.020353
# Pennsylvania           0.009760            11.0      0.009760  2477.965405
# Delaware                -74.969814
# New Mexico             -305.229766
# Hawaii                 -183.038205
# Idaho                  -279.951755
# Nebraska               -316.384522
# Montana                -157.044211
# Alaska                  -99.864821
# South Dakota           -133.533263
# North Dakota           -108.222619
# West Virginia          -304.657895
# Wyoming                 -68.592208

# %%
covid.describe()
# Out:
#          population  totalConfirmed  infectionRate  totalDeaths  deathRate  \
# count  5.100000e+01       51.000000      51.000000    40.000000  51.000000
# mean   6.496457e+06     1255.607843       0.000137    17.750000   0.013803
# std    7.450656e+06     4309.066252       0.000228    28.368229   0.013232
# min    5.670250e+05       39.000000       0.000022     1.000000   0.000000
# 25%    1.802113e+06      123.500000       0.000049     2.750000   0.003187
# 50%    4.499692e+06      346.000000       0.000072     6.500000   0.011111
# 75%    7.587794e+06      893.500000       0.000117    12.500000   0.021072
# max    3.993749e+07    30811.000000       0.001585   123.000000   0.056911
#
#        totalRecovered  recoveryRate     expected         delta
# count       51.000000     51.000000    51.000000  5.100000e+01
# mean        11.882353      0.018221  1255.607843 -3.733832e-14
# std         45.825603      0.073424  1440.031507  4.032390e+03
# min          0.000000      0.000000   109.592208 -5.101950e+03
# 25%          0.000000      0.000000   348.304825 -7.327003e+02
# 50%          0.000000      0.000000   869.681555 -3.052298e+02
# 75%          2.000000      0.002425  1466.537024 -1.040437e+02
# max        285.000000      0.425087  7718.949990  2.705363e+04

# %%
df3 = pd.read_json(url)
df3.head(50)
# Out:
#        id displayName                                              areas  \
# 0   world      Global  {'id': 'chinamainland', 'displayName': 'China ...
# 1   world      Global  {'id': 'italy', 'displayName': 'Italy', 'areas...
# 2   world      Global  {'id': 'unitedstates', 'displayName': 'United ...
# 3   world      Global  {'id': 'spain', 'displayName': 'Spain', 'areas...
# 4   world      Global  {'id': 'germany', 'displayName': 'Germany', 'a...
# 5   world      Global  {'id': 'iran', 'displayName': 'Iran', 'areas':...
# 6   world      Global  {'id': 'france', 'displayName': 'France', 'are...
# 7   world      Global  {'id': 'switzerland', 'displayName': 'Switzerl...
# 8   world      Global  {'id': 'southkorea', 'displayName': 'South Kor...
# 9   world      Global  {'id': 'unitedkingdom', 'displayName': 'United...
# 10  world      Global  {'id': 'netherlands', 'displayName': 'Netherla...
# 11  world      Global  {'id': 'austria', 'displayName': 'Austria', 'a...
# 12  world      Global  {'id': 'belgium', 'displayName': 'Belgium', 'a...
# 13  world      Global  {'id': 'canada', 'displayName': 'Canada', 'are...
# 14  world      Global  {'id': 'norway', 'displayName': 'Norway', 'are...
# 15  world      Global  {'id': 'portugal', 'displayName': 'Portugal', ...
# 16  world      Global  {'id': 'sweden', 'displayName': 'Sweden', 'are...
# 17  world      Global  {'id': 'australia', 'displayName': 'Australia'...
# 18  world      Global  {'id': 'brazil', 'displayName': 'Brazil', 'are...
# 19  world      Global  {'id': 'israel', 'displayName': 'Israel', 'are...
# 20  world      Global  {'id': 'turkey', 'displayName': 'Turkey', 'are...
# 21  world      Global  {'id': 'denmark', 'displayName': 'Denmark', 'a...
# 22  world      Global  {'id': 'malaysia', 'displayName': 'Malaysia', ...
# Out:
#                         id displayName  \
# 0     newyork_unitedstates    New York
# 1   newjersey_unitedstates  New Jersey
# 2  california_unitedstates  California
# 3  washington_unitedstates  Washington
# 4   louisiana_unitedstates   Louisiana
#
#                                                areas  totalConfirmed  \
# 0  [{'id': 'newyork_newyork_unitedstates', 'displ...           30811
# 1  [{'id': 'atlantic_newjersey_unitedstates', 'di...            3675
# 2  [{'id': 'losangeles_california_unitedstates', ...            2266
# 3  [{'id': 'king_washington_unitedstates', 'displ...            2469
# 4  [{'id': 'jeffersonparish_louisiana_unitedstate...            1388
#
#    totalDeaths  totalRecovered               lastUpdated        lat  \
# 0        285.0             NaN  2020-03-25T18:32:26.616Z  42.937080
# 1         44.0             2.0  2020-03-25T18:32:26.616Z  40.138779
# 2         42.0             6.0  2020-03-25T18:32:26.616Z  37.255100
# 3        123.0           124.0  2020-03-25T18:32:26.616Z  47.411297
# 4         46.0             NaN  2020-03-25T18:32:26.616Z  30.966511
#
#          long      parentId
# 0  -75.610695  unitedstates
# 1  -74.676910  unitedstates
# 2 -119.617523  unitedstates
# 3 -120.556267  unitedstates
# 4  -91.851906  unitedstates

# %%
counties = pd.json_normalize(data=j['areas'][2]['areas'], record_path='areas')
counties.head(100)
# Out:
#                                     id  displayName areas  totalConfirmed  \
# 0         newyork_newyork_unitedstates     New York    []           17856
# 1     westchester_newyork_unitedstates  Westchester    []            4691
# 2          nassau_newyork_unitedstates       Nassau    []            3285
# 3         suffolk_newyork_unitedstates      Suffolk    []            2260
# 4        rockland_newyork_unitedstates     Rockland    []             968
# ..                                 ...          ...   ...             ...
# 95      fresno_california_unitedstates       Fresno    []              13
# 96  stanislaus_california_unitedstates   Stanislaus    []              11
# 97    imperial_california_unitedstates     Imperial    []               6
# 98      madera_california_unitedstates       Madera    []               6
# 99   sanbenito_california_unitedstates   San Benito    []               6
#
#     totalDeaths  totalRecovered               lastUpdated        lat  \
# 0           NaN             NaN  2020-03-25T18:57:37.994Z  40.774364
# 1           NaN             NaN  2020-03-25T18:57:37.994Z  41.151657
# 2           NaN             NaN  2020-03-25T18:57:37.994Z  40.756714
# 3           NaN             NaN  2020-03-25T18:57:37.994Z  40.966293
# 4           NaN             NaN  2020-03-25T18:57:37.994Z  41.152374
# ..          ...             ...                       ...        ...
# 95          NaN             NaN  2020-03-25T18:57:37.994Z  36.758274
# 96          NaN             NaN  2020-03-25T18:57:37.994Z  37.559326
# 97          NaN             NaN  2020-03-25T18:57:37.994Z  33.039684
# 98          NaN             1.0  2020-03-25T18:57:37.994Z  37.218010
# 99          1.0             2.0  2020-03-25T18:57:37.994Z  36.605598
#
#           long                 parentId
# 0   -73.969772     newyork_unitedstates
# 1   -73.753326     newyork_unitedstates
# 2   -73.591393     newyork_unitedstates
# 3   -72.687111     newyork_unitedstates
# 4   -74.024010     newyork_unitedstates
# ..         ...                      ...
# 95 -119.649193  california_unitedstates
# 96 -120.997665  california_unitedstates
# 97 -115.365303  california_unitedstates
# 98 -119.762726  california_unitedstates
# 99 -121.074928  california_unitedstates
#
# [100 rows x 10 columns]
